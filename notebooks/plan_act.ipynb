# %%
import pddlgym
import gym
import imageio
from pddlgym_planners.ff import FF  # FastForward
from pddlgym_planners.fd import FD  # FastDownward
import os
import matplotlib.pyplot as plt

# %%
for env in gym.envs.registry.keys():
    if 'Snake' in env:
        print(env)
# Out:
# PDDLEnvSnake-v0
# PDDLEnvSnakeTest-v0

# %%
env_name = 'PDDLEnvSnake-v0'

env = pddlgym.make(env_name)
env.fix_problem_index(1)
obs, debug_info = env.reset()

plt.imshow(env.render())

# %%
env.problems
# Out:
# [<pddlgym.parser.PDDLProblemParser at 0x12b5c12a0>,
#  <pddlgym.parser.PDDLProblemParser at 0x12b5c0c70>]

# %% [markdown]
# Equivalent CLI command for FF planner on snake problem 1
#
# ```
# /Users/vla/umd/CMSC722_ai_planning/CMSC722_project/pddlgym_planners/pddlgym_planners/FF-v2.3/ff -o /Users/vla/umd/CMSC722_ai_planning/CMSC722_project/pddlgym/pddlgym/pddl/snake.pddl -f /Users/vla/umd/CMSC722_ai_planning/CMSC722_project/pddlgym/pddlgym/pddl/snake/p01.pddl
#
# ``

# %%
for env_name in ['PDDLEnvSnake-v0', 'PDDLEnvSnakeTest-v0']:

    # for planner_name, planner in zip(['FF', 'FD'], [FF, FD]):
    for planner_name, planner in zip(['FD'], [FD]):


        exp_dir = f'./{env_name}/{planner_name}'
        os.makedirs(exp_dir, exist_ok=True)

        env = pddlgym.make(env_name)
        obs, debug_info = env.reset()

        # render env and save initial state as image
        img = env.render()
        imageio.imsave(os.path.join(exp_dir, "snake_p01_step_00.png"), img)


        # Planning with PDDL planner
        planner = planner()
        state, _ = env.reset()
        plan = planner(env.domain, state)
        # print("Plan:", ff_planner(env.domain, state))

        state_index = 1
        for action in plan:
            print(action)
            print("Obs:", obs)
            print("Act:", action)
            obs, reward, done, truncated, debug_info = env.step(action)

            img = env.render()
            imageio.imsave(os.path.join(exp_dir, f"snake_p01_step_{state_index:02d}.png"), img)
            state_index += 1


        print("Final obs, reward, done:", obs, reward, done)

        len(plan)

        print("Statistics:", planner.get_statistics())
# Out:
# Instantiating FD with --alias seq-opt-lmcut
# ---------------------------------------------------------------------------
# PlanningFailure                           Traceback (most recent call last)
# Cell In[6], line 21
#      19 planner = planner()
#      20 state, _ = env.reset()
# ---> 21 plan = planner(env.domain, state)
#      22 # print("Plan:", ff_planner(env.domain, state))
#      24 state_index = 1
#
# File ~/umd/CMSC722_ai_planning/CMSC722_project/pddlgym_planners/pddlgym_planners/pddl_planner.py:48, in PDDLPlanner.__call__(self, domain, state, horizon, timeout, return_files, translate_separately)
#      46     os.remove(sas_file)
#      47 else:
# ---> 48     pddl_plan = self.plan_from_pddl(
#      49         dom_file, prob_file, horizon=horizon,
#      50         timeout=timeout, remove_files=(not return_files))
#      51 plan = [self._plan_step_to_action(domain, state,
#      52                                   act_predicates, plan_step)
#      53         for plan_step in pddl_plan]
#      54 if return_files:
#
# File ~/umd/CMSC722_ai_planning/CMSC722_project/pddlgym_planners/pddlgym_planners/pddl_planner.py:71, in PDDLPlanner.plan_from_pddl(self, dom_file, prob_file, horizon, timeout, remove_files)
#      69 if time.time()-start_time > timeout:
#      70     raise PlanningTimeout("Planning timed out!")
# ---> 71 pddl_plan = self._output_to_plan(output)
#      72 if len(pddl_plan) > horizon:
#      73     raise PlanningFailure("PDDL planning failed due to horizon")
#
# File ~/umd/CMSC722_ai_planning/CMSC722_project/pddlgym_planners/pddlgym_planners/fd.py:95, in FD._output_to_plan(self, output)
#      93         raise PlanningFailure("Error on output's plan cost format: {}".format(plan_cost[0]))
#      94 if "Solution found!" not in output:
# ---> 95     raise PlanningFailure("Plan not found with FD! Error: {}".format(
#      96         output))
#      97 if "Plan length: 0 step" in output:
#      98     return []
#
# PlanningFailure: Plan not found with FD! Error: INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /Users/vla/.local/share/mamba/envs/CMSC722/bin/python3 -m translate /var/folders/9s/yxmqx5dj6rb86f2zsgmn5z2m0000gn/T/tmpw70uafes /var/folders/9s/yxmqx5dj6rb86f2zsgmn5z2m0000gn/T/tmpr02ra73o --sas-file /var/folders/9s/yxmqx5dj6rb86f2zsgmn5z2m0000gn/T/tmpbqqo0_2w
# Parsing...
#
# Found the following duplicate objects: dummypoint
# translate exit code: 31
#
# Driver aborting after translate
# INFO     Planner time: 0.03s

# %%
len(plan)
# Out:
# 29

# %%
# !magick -delay 30 {exp_dir}/*snake* {exp_dir}/animation.gif
