# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# results from experiments/READEME.md
results = [
    ("p0", "FF", 29, 0.1),
    ("p0", "HTN", 27, 0.008530),
    ("p1", "FF", 41, 0.03),
    ("p1", "HTN", 47, 0.015784),
    ("p2", "FF", 41,  0.11),
    ("p2", "HTN", 35, 0.020910),
    ("p3", "FF", 74, 0.88),
    ("p3", "HTN", 76, 0.046762),
    ("p4", "FF", np.nan, np.nan),
    ("p4", "HTN", 118, 0.075316)
]

colnames = ["Problem", "Planner", "Plan Length", "Planning Time (s)"]
df_results = pd.DataFrame(results, columns=colnames)

df_results
# Out:
#   Problem Planner  Plan Length  Planning Time (s)
# 0      p0      FF         29.0           0.100000
# 1      p0     HTN         27.0           0.008530
# 2      p1      FF         41.0           0.030000
# 3      p1     HTN         47.0           0.015784
# 4      p2      FF         41.0           0.110000
# 5      p2     HTN         35.0           0.020910
# 6      p3      FF         74.0           0.880000
# 7      p3     HTN         76.0           0.046762
# 8      p4      FF          NaN                NaN
# 9      p4     HTN        118.0           0.075316

# %%
sns.barplot(
    data=df_results,
    x = "Problem",
    y = "Plan Length",
    hue = "Planner"
)
# Out:
# <Axes: xlabel='Problem', ylabel='Plan Length'>

# %%
sns.barplot(
    data=df_results,
    x = "Problem",
    y = "Planning Time (s)",
    hue = "Planner"
)
# Out:
# <Axes: xlabel='Problem', ylabel='Planning Time (s)'>
