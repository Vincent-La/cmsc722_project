# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# results from experiments/READEME.md
results = [
    (0, "FF", 29, 0.1),
    (0, "HTN", 27, 0.008530),
    (1, "FF", 41, 0.03),
    (1, "HTN", 47, 0.015784),
    (2, "FF", 41,  0.11),
    (2, "HTN", 35, 0.020910),
    (3, "FF", 74, 0.88),
    (3, "HTN", 76, 0.046762),
    (4, "FF", np.nan, np.nan),
    (4, "HTN", 118, 0.075316)
]

colnames = ["Problem", "Planner", "Plan Length", "Planning Time (s)"]
df_results = pd.DataFrame(results, columns=colnames)

df_results
# Out:
#    Problem Planner  Plan Length  Planning Time (s)
# 0        0      FF         29.0           0.100000
# 1        0     HTN         27.0           0.008530
# 2        1      FF         41.0           0.030000
# 3        1     HTN         47.0           0.015784
# 4        2      FF         41.0           0.110000
# 5        2     HTN         35.0           0.020910
# 6        3      FF         74.0           0.880000
# 7        3     HTN         76.0           0.046762
# 8        4      FF          NaN                NaN
# 9        4     HTN        118.0           0.075316

# %%
sns.barplot(
    data=df_results,
    x = "Problem",
    y = "Plan Length",
    hue = "Planner"
)
# Out:
# <Axes: xlabel='Problem', ylabel='Plan Length'>

# %%
sns.barplot(
    data=df_results,
    x = "Problem",
    y = "Planning Time (s)",
    hue = "Planner"
)
# Out:
# <Axes: xlabel='Problem', ylabel='Planning Time (s)'>
